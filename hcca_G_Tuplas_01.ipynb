# %% [markdown]
# <a href="https://colab.research.google.com/github/hiramaralIA/CETAM_IA_AULAS_PYTHON/blob/main/hcca_G_Tuplas_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tuplas
#
# ### Estrutura:
#
# tupla = (valor, valor, valor, ...)
#
# ### Diferença
#
# Parece uma lista, mas é imutável.
#
# ### Vantagens:
#
# - Mais eficiente (em termos de performance)
# - Protege a base de dados (por ser imutável)
# - Muito usado para dados heterogêneos
#
# ### Criando tuplas

# %%
vendas = ('Lira', '25/08/2020', '15/02/1994', 2000, 'Estagiário')
print(vendas)
# Out:
# ('Lira', '25/08/2020', '15/02/1994', 2000, 'Estagiário')

# %% [markdown]
# ### Acessando o valor de uma tupla

# %%
vendas[3] = 3000

nome = vendas[0]
data_contratacao = vendas[1]
data_nascimento = vendas[2]
salario = vendas[3]
cargo = vendas[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1cce8a23dea7> in <module>
# ----> 1 vendas[3] = 3000
#       2
#       3 nome = vendas[0]
#       4 data_contratacao = vendas[1]
#       5 data_nascimento = vendas[2]
#
# TypeError: 'tuple' object does not support item assignment
